# %%
import os
import time
import requests
import pandas as pd
import json
from pathlib import Path
from dotenv import load_dotenv

load_dotenv(".env")
TMDB_TOKEN = os.getenv("TMDB_TOKEN")

OUTPUT_FILE = "Q6.csv"

tmdb_headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {TMDB_TOKEN}"
}

BASE_URL = "https://api.themoviedb.org/3"

# %% [markdown]
# ## Getter

# %%
# LLM for retrying the collectionprocess
def tmdb_get(endpoint, params=None, retries=3):
    if params is None:
        params = {}
    url = BASE_URL + endpoint
    for attempt in range(retries):
        try:
            r = requests.get(url, headers=tmdb_headers, params=params, timeout=10)
            r.raise_for_status()
            return r.json()
        except requests.exceptions.Timeout:
            print(f"Timeout, retry {attempt + 1}/{retries}...")
            time.sleep(2)
        except requests.exceptions.RequestException as e:
            print(f"Fehler: {e}")
            time.sleep(2)
    return None

# %% [markdown]
# ## Collect Movies

# %%
def collect_movies(year, pages=30):
    all_movies = []
    for page in range(1, pages + 1):
        data = tmdb_get(
            "/discover/movie",
            params={
                "primary_release_year": year,
                "sort_by":              "popularity.desc",
                #"vote_count.gte":       100,
                "page":                 page,
            }
        )
        all_movies.extend(data["results"])
        time.sleep(0.25)
    return pd.DataFrame(all_movies)

# %% [markdown]
# ## Load Movies

# %%
frames = []

for year in range(2000, 2025):
    frames.append(collect_movies(year, pages=30))
    print(f"Year {year} loaded")

df_movies = pd.concat(frames, ignore_index=True).drop_duplicates("id")
print(f"all {len(df_movies)} Movies")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 frames = []
#       3 for year in range(2000, 2025):
# ----> 4     frames.append(collect_movies(year, pages=30))
#       5     print(f"Jahr {year} geladen")
#       7 df_movies = pd.concat(frames, ignore_index=True).drop_duplicates("id")
#
# Cell In[3], line 4, in collect_movies(year, pages)
#       2 all_movies = []
#       3 for page in range(1, pages + 1):
# ----> 4     data = tmdb_get(
#       5         "/discover/movie",
#       6         params={
#       7             "primary_release_year": year,
#       8             "sort_by":              "popularity.desc",
#       9             #"vote_count.gte":       100,
#      10             "page":                 page,
#      11         }
#      12     )
#      13     all_movies.extend(data["results"])
#      14     time.sleep(0.25)
#
# Cell In[2], line 7, in tmdb_get(endpoint, params, retries)
#       5 for attempt in range(retries):
#       6     try:
# ----> 7         r = requests.get(url, headers=tmdb_headers, params=params, timeout=10)
#       8         r.raise_for_status()
#       9         return r.json()
#
# File ~/.var/app/com.vscodium.codium/data/python/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.var/app/com.vscodium.codium/data/python/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.var/app/com.vscodium.codium/data/python/lib/python3.13/site-packages/requests/sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)    573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File ~/.var/app/com.vscodium.codium/data/python/lib/python3.13/site-packages/requests/sessions.py:490, in Session.prepare_request(self, request)
#     481     auth = get_netrc_auth(request.url)
#     483 p = PreparedRequest()
#     484 p.prepare(
#     485     method=request.method.upper(),
#     486     url=request.url,
#     487     files=request.files,
#     488     data=request.data,
#     489     json=request.json,
# --> 490     headers=merge_setting(
#     491         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     492     ),
#     493     params=merge_setting(request.params, self.params),
#     494     auth=merge_setting(auth, self.auth),
#     495     cookies=merged_cookies,
#     496     hooks=merge_hooks(request.hooks, self.hooks),
#     497 )
#     498 return p
#
# File ~/.var/app/com.vscodium.codium/data/python/lib/python3.13/site-packages/requests/sessions.py:80, in merge_setting(request_setting, session_setting, dict_class)
#      77     return request_setting
#      79 merged_setting = dict_class(to_key_val_list(session_setting))
# ---> 80 merged_setting.update(to_key_val_list(request_setting))
#      82 # Remove keys that are set to None. Extract keys first to avoid altering
#      83 # the dictionary during iteration.
#      84 none_keys = [k for (k, v) in merged_setting.items() if v is None]
#
# File <frozen _collections_abc>:993, in update(self, other, **kwds)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Load Details

# %%
rows = []

for _, movie in df_movies.iterrows():
    details = tmdb_get(f"/movie/{movie['id']}")
    
    if details is None:
        continue
    
    if not details.get("belongs_to_collection"):
        continue
    
    budget  = details.get("budget",  0)
    revenue = details.get("revenue", 0)
    
    if budget == 0 or revenue == 0:
        continue
    
    rows.append({
        "collection_id":   details["belongs_to_collection"]["id"],
        "collection_name": details["belongs_to_collection"]["name"],
        "title":           details["title"],
        "release_date":    details["release_date"],
        "budget":          budget,
        "revenue":         revenue,
        "roi":             round(revenue / budget, 2),
        "rating":          details["vote_average"],
        "vote_count":      details["vote_count"],
    })
    
    time.sleep(0.25)

print(f"Franchise-Movies: {len(rows)}")
# Out:
# Timeout, retry 1/3...
# Franchise-Filme: 712

# %% [markdown]
# ## Build Dataframe

# %%
df = pd.DataFrame(rows)
df["release_date"] = pd.to_datetime(df["release_date"])
df = df.sort_values(["collection_id", "release_date"]).reset_index(drop=True)

df["part"] = df.groupby("collection_id").cumcount()

counts = df.groupby("collection_id")["title"].transform("count")
df = df[counts >= 2].reset_index(drop=True)

print(f"Franchises: {df['collection_id'].nunique()}")
print(f"Movies: {len(df)}")
# Out:
# Franchises: 162
# Filme gesamt: 414

# %% [markdown]
# ## Compaire

# %%
originals = df[df["part"] == 0][["collection_id", "revenue", "roi", "rating"]].rename(columns={
    "revenue": "orig_revenue",
    "roi":     "orig_roi",
    "rating":  "orig_rating"
})

df = df.merge(originals, on="collection_id", how="left")

df.loc[df["part"] == 0, ["orig_revenue", "orig_roi", "orig_rating"]] = None

df["revenue_diff"] = df["revenue"] - df["orig_revenue"]
df["roi_diff"]     = df["roi"]     - df["orig_roi"]
df["rating_diff"]  = df["rating"]  - df["orig_rating"]

df.head(10)
# Out:
#    collection_id                   collection_name  \
# 0             10              Star Wars Collection
# 1             10              Star Wars Collection
# 2             10              Star Wars Collection
# 3             10              Star Wars Collection
# 4             10              Star Wars Collection
# 5             84          Indiana Jones Collection
# 6             84          Indiana Jones Collection
# 7            119  The Lord of the Rings Collection
# 8            119  The Lord of the Rings Collection
# 9            119  The Lord of the Rings Collection
#
#                                                title release_date     budget  \
# 0       Star Wars: Episode II - Attack of the Clones   2002-05-15  120000000
# 1       Star Wars: Episode III - Revenge of the Sith   2005-05-17  113000000
# 2                       Star Wars: The Force Awakens   2015-12-15  245000000
# 3                           Star Wars: The Last Jedi   2017-12-13  300000000
# 4                   Star Wars: The Rise of Skywalker   2019-12-18  489900000
# 5  Indiana Jones and the Kingdom of the Crystal S...   2008-05-21  185000000
# 6              Indiana Jones and the Dial of Destiny   2023-06-25  294700000
# 7  The Lord of the Rings: The Fellowship of the Ring   2001-12-18   93000000
# 8              The Lord of the Rings: The Two Towers   2002-12-18   79000000
# 9      The Lord of the Rings: The Return of the King   2003-12-17   94000000
#
#       revenue    roi  rating  vote_count  part  orig_revenue  orig_roi  \
# 0   649398328   5.41   6.589       14142     0           NaN       NaN
# 1   850000000   7.52   7.460       14724     1   649398328.0      5.41
# 2  2068223624   8.44   7.250       20327     2   649398328.0      5.41
# 3  1332698830   4.44   6.757       16134     3   649398328.0      5.41
# 4  1074144248   2.19   6.272       10664     4   649398328.0      5.41
# 5   786636033   4.25   6.019        8900     0           NaN       NaN
# 6   383963057   1.30   6.513        4028     1   786636033.0      4.25
# 7   871368364   9.37   8.429       27119     0           NaN       NaN
# 8   926287400  11.73   8.413       23529     1   871368364.0      9.37
# 9  1118888979  11.90   8.494       26134     2   871368364.0      9.37
#
#    orig_rating  revenue_diff  roi_diff  rating_diff
# 0          NaN           NaN       NaN          NaN
# 1        6.589  2.006017e+08      2.11        0.871
# 2        6.589  1.418825e+09      3.03        0.661
# 3        6.589  6.833005e+08     -0.97        0.168
# 4        6.589  4.247459e+08     -3.22       -0.317
# 5          NaN           NaN       NaN          NaN
# 6        6.019 -4.026730e+08     -2.95        0.494
# 7          NaN           NaN       NaN          NaN
# 8        8.429  5.491904e+07      2.36       -0.016
# 9        8.429  2.475206e+08      2.53        0.065

# %% [markdown]
# ## Store

# %%
df.to_csv("Q6.csv", index=False)
print("stored.")
# Out:
# Gespeichert.
