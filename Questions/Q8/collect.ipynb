# %% [markdown]
# Imports

# %%
import pandas as pd
import re

# %%
oscars_merged = pd.read_csv("oscars_movies_merged.csv")

# %%
oscars_merged = oscars_merged[
    (oscars_merged["budget"] > 0) &
    (oscars_merged["revenue"] > 0)
]
