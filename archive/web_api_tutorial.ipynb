# %% [markdown]
# # RestAPIs
#
# Call using requests library (https://realpython.com/python-requests/)
#
# - Make requests using the most common HTTP methods
# - Customize your requests’ headers and data using the query string and message body
# - Inspect data from your requests and responses
# - Make authenticated requests

# %%
import requests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import requests
#
# ModuleNotFoundError: No module named 'requests'

# %%
response = requests.get('https://www.uni-kiel.de/de/')
response
# Out:
# <Response [200]>

# %% [markdown]
# ## Status Codes
#
# 200 – OK. The request was successful. The answer itself depends on the method used (GET, POST, etc.) and the API specification.
#
# 204 – No Content. The server successfully processed the request and did not return any content.
#
# 301 – Moved Permanently. The server responds that the requested page (endpoint) has been moved to another address and redirects to this address.
#
# 400 – Bad Request. The server cannot process the request because the client-side errors (incorrect request format).
#
# 401 – Unauthorized. Occurs when authentication was failed, due to incorrect credentials or even their absence.
#
# 403 – Forbidden. Access to the specified resource is denied.
#
# 404 – Not Found. The requested resource was not found on the server.
#
# 500 – Internal Server Error. Occurs when an unknown error has occurred on the server.
#
# Read more here: https://rapidapi.com/blog/how-to-use-an-api-with-python/

# %% [markdown]
# # no parameters: Kanye API
# - Simple restAPI
# - extract json resonse

# %%
api_url = "https://api.kanye.rest/"
response = requests.get(api_url)
response = response.json()#['quote']

# %%
response
# Out:
# {'quote': 'Style is genderless'}

# %% [markdown]
# # with parameters: Cocktail API

# %%
parameter_ = 'Pina Colada' # 'margarita'
url = f'https://www.thecocktaildb.com/api/json/v1/1/search.php?s={parameter_}'
cocktail = requests.get(url).json()
cocktail
# Out:
# {'drinks': [{'idDrink': '17207',
#    'strDrink': 'Pina Colada',
#    'strDrinkAlternate': None,
#    'strTags': 'IBA,ContemporaryClassic',
#    'strVideo': None,
#    'strCategory': 'Ordinary Drink',
#    'strIBA': 'Contemporary Classics',
#    'strAlcoholic': 'Alcoholic',
#    'strGlass': 'Collins glass',
#    'strInstructions': 'Mix with crushed ice in blender until smooth. Pour into chilled glass, garnish and serve.',
#    'strInstructionsES': 'Mezclar con hielo picado en la batidora hasta obtener una mezcla homogénea. Verter en un vaso frío, decorar y servir.',
#    'strInstructionsDE': 'Mit zerstoßenem Eis im Mixer mischen, bis es glatt ist. In ein gekühltes Glas geben, garnieren und servieren.',
#    'strInstructionsFR': "Mélanger au mixeur avec de la glace pilée jusqu'à obtention d'un mélange homogène. Verser dans un verre réfrigéré, garnir et servir.",
#    'strInstructionsIT': 'Mescolare con ghiaccio tritato in un frullatore fino a che liscio.\r\nVersare in un bicchiere freddo, guarnire e servire.',
#    'strInstructionsZH-HANS': None,
#    'strInstructionsZH-HANT': None,
#    'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/upgsue1668419912.jpg',
#    'strIngredient1': 'Light rum',
#    'strIngredient2': 'Coconut milk',
#    'strIngredient3': 'Pineapple',
#    'strIngredient4': None,
#    'strIngredient5': None,
#    'strIngredient6': None,
#    'strIngredient7': None,
#    'strIngredient8': None,
#    'strIngredient9': None,
#    'strIngredient10': None,
#    'strIngredient11': None,
#    'strIngredient12': None,
#    'strIngredient13': None,
#    'strIngredient14': None,
#    'strIngredient15': None,
#    'strMeasure1': '3 oz ',
#    'strMeasure2': '3 tblsp ',
#    'strMeasure3': '3 tblsp ',
#    'strMeasure4': None,
#    'strMeasure5': None,
#    'strMeasure6': None,
#    'strMeasure7': None,
#    'strMeasure8': None,
#    'strMeasure9': None,
#    'strMeasure10': None,
#    'strMeasure11': None,
#    'strMeasure12': None,
#    'strMeasure13': None,
#    'strMeasure14': None,
#    'strMeasure15': None,
#    'strImageSource': 'https://www.thecocktaildb.com/images/media/drink/upgsue1668419912.jpg',
#    'strImageAttribution': 'TheCocktailDB',
#    'strCreativeCommonsConfirmed': 'Yes',
#    'dateModified': '2017-09-02 17:55:46'}]}

# %% [markdown]
# # API key authentification: Holiday API

# %%
from requests.auth import HTTPBasicAuth

## username and password
my_auth = HTTPBasicAuth('api_key', 'KwqlmdYMJbRCObh7j2doZQK5Oq1ZcWEj')

# %%
parameter_country = "PT"
parameter_year = 2024
holidays = requests.get(f'https://calendarific.com/api/v2/holidays/?&country={parameter_country}&year={parameter_year}', 
                        auth=my_auth)

# %%
holidays.json()
# Out:
# {'meta': {'code': 200},
#  'response': {'holidays': [{'name': "New Year's Day",
#     'description': "New Year's Day is the first day of the year, or January 1, in the Gregorian calendar.",
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-01-01',
#      'datetime': {'year': 2024, 'month': 1, 'day': 1}},
#     'type': ['National holiday'],
#     'primary_type': 'National holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/new-year-day',
#     'urlid': 'portugal/new-year-day',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Carnival / Shrove Tuesday / Pancake Day',
#     'description': 'Shrove Tuesday is a religious holiday before the fasting period of Lent. It is celebrated by eating pancakes and holding Carnival parades.',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-02-13',
#      'datetime': {'year': 2024, 'month': 2, 'day': 13}},
#     'type': ['Common local holiday'],
#     'primary_type': 'Optional Holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/carnival',
#     'urlid': 'portugal/carnival',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': "Valentine's Day",
#     'description': "February 14 is Valentine's Day or Saint Valentine's Feast. The day of love owes its origins to ancient Roman and European Christian traditions.",
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-02-14',
#      'datetime': {'year': 2024, 'month': 2, 'day': 14}},
#     'type': ['Observance'],
#     'primary_type': 'Observance',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/valentine-day',
#     'urlid': 'portugal/valentine-day',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': "St. Joseph's Day",
#     'description': "St. Joseph's Day is a district holiday in Portugal",
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-03-19',
#      'datetime': {'year': 2024, 'month': 3, 'day': 19}},
#     'type': ['Local holiday'],
#     'primary_type': 'District Holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/st-joseph-day',
#     'urlid': 'portugal/st-joseph-day',
#     'locations': 'Santarém',
#     'states': [{'id': 852,
#       'abbrev': None,
#       'name': 'Santarém',
#       'exception': None,
#       'iso': 'pt-14'}]},
#    {'name': "Father's Day",
#     'description': "Father's Day celebrates fatherhood and male parenting on different dates worldwide.",
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-03-19',
#      'datetime': {'year': 2024, 'month': 3, 'day': 19}},
#     'type': ['Observance'],
#     'primary_type': 'Observance',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/father-day',
#     'urlid': 'portugal/father-day',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'March Equinox',
#     'description': 'March Equinox in Portugal (Lisbon)',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-03-20T03:06:28+00:00',
#      'datetime': {'year': 2024,
#       'month': 3,
#       'day': 20,
#       'hour': 3,
#       'minute': 6,
#       'second': 28},
#      'timezone': {'offset': '+00:00',
#       'zoneabb': 'WET',
#       'zoneoffset': 0,
#       'zonedst': 0,
#       'zonetotaloffset': 0}},
#     'type': ['Season'],
#     'primary_type': 'Season',
#     'canonical_url': 'https://calendarific.com/holiday/seasons/vernal-equinox',
#     'urlid': 'seasons/vernal-equinox',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Good Friday',
#     'description': 'Good Friday is a global Christian observance two days before Easter Sunday.',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-03-29',
#      'datetime': {'year': 2024, 'month': 3, 'day': 29}},
#     'type': ['National holiday'],
#     'primary_type': 'National holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/good-friday',
#     'urlid': 'portugal/good-friday',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Easter Sunday',
#     'description': "Easter Sunday commemorates Jesus Christ's resurrection, according to Christian belief.",
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-03-31',
#      'datetime': {'year': 2024, 'month': 3, 'day': 31}},
#     'type': ['National holiday'],
#     'primary_type': 'National holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/easter-sunday',
#     'urlid': 'portugal/easter-sunday',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Daylight Saving Time starts',
#     'description': 'Daylight Saving Time starts in Portugal',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-03-31T01:00:00+00:00',
#      'datetime': {'year': 2024,
#       'month': 3,
#       'day': 31,
#       'hour': 1,
#       'minute': 0,
#       'second': 0},
#      'timezone': {'offset': '+00:00',
#       'zoneabb': 'WET',
#       'zoneoffset': 0,
#       'zonedst': 0,
#       'zonetotaloffset': 0}},
#     'type': ['Clock change/Daylight Saving Time'],
#     'primary_type': 'Clock change/Daylight Saving Time',
#     'canonical_url': 'https://calendarific.com/holiday/',
#     'urlid': None,
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Our Lady of Mércoles',
#     'description': 'Our Lady of Mércoles is a district holiday in Portugal',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-04-16',
#      'datetime': {'year': 2024, 'month': 4, 'day': 16}},
#     'type': ['Local holiday'],
#     'primary_type': 'District Holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/our-lady-of-mercoles',
#     'urlid': 'portugal/our-lady-of-mercoles',
#     'locations': 'Castelo Branco',
#     'states': [{'id': 843,
#       'abbrev': None,
#       'name': 'Castelo Branco',
#       'exception': None,
#       'iso': 'pt-05'}]},
#    {'name': 'Liberty Day',
#     'description': 'Liberty Day is a national holiday in Portugal',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-04-25',
#      'datetime': {'year': 2024, 'month': 4, 'day': 25}},
#     'type': ['National holiday'],
#     'primary_type': 'National holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/liberty-day',
#     'urlid': 'portugal/liberty-day',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Labor Day / May Day',
#     'description': "Labor Day, International Workers' Day, and May Day, is a day off for workers in many countries around the world.",
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-05-01',
#      'datetime': {'year': 2024, 'month': 5, 'day': 1}},
#     'type': ['National holiday'],
#     'primary_type': 'National holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/labor-day',
#     'urlid': 'portugal/labor-day',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': "Mother's Day",
#     'description': "Mother's Day celebrates the achievements and efforts of mothers and mother figures.",
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-05-05',
#      'datetime': {'year': 2024, 'month': 5, 'day': 5}},
#     'type': ['Observance'],
#     'primary_type': 'Observance',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/mother-day',
#     'urlid': 'portugal/mother-day',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Ascension Day',
#     'description': 'Ascension Day is the 40th day of Easter. It is a religious holiday that commemorates the ascension of Jesus Christ into heaven.',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-05-09',
#      'datetime': {'year': 2024, 'month': 5, 'day': 9}},
#     'type': ['Local holiday'],
#     'primary_type': 'District Holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/ascension-day',
#     'urlid': 'portugal/ascension-day',
#     'locations': 'Beja',
#     'states': [{'id': 841,
#       'abbrev': None,
#       'name': 'Beja',
#       'exception': None,
#       'iso': 'pt-02'}]},
#    {'name': "St. Joana's Day",
#     'description': "St. Joana's Day is a district holiday in Portugal",
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-05-12',
#      'datetime': {'year': 2024, 'month': 5, 'day': 12}},
#     'type': ['Local holiday'],
#     'primary_type': 'District Holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/st-joana-day',
#     'urlid': 'portugal/st-joana-day',
#     'locations': 'Aveiro',
#     'states': [{'id': 840,
#       'abbrev': None,
#       'name': 'Aveiro',
#       'exception': None,
#       'iso': 'pt-01'}]},
#    {'name': 'Azores Day',
#     'description': 'Azores Day is a regional holiday in Portugal',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-05-20',
#      'datetime': {'year': 2024, 'month': 5, 'day': 20}},
#     'type': ['Local holiday'],
#     'primary_type': 'Regional Holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/azores-day',
#     'urlid': 'portugal/azores-day',
#     'locations': 'Azores',
#     'states': [{'id': 211,
#       'abbrev': None,
#       'name': 'Azores',
#       'exception': None,
#       'iso': 'pt-20'}]},
#    {'name': 'Leiria Day',
#     'description': 'Leiria Day is a district holiday in Portugal',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-05-22',
#      'datetime': {'year': 2024, 'month': 5, 'day': 22}},
#     'type': ['Local holiday'],
#     'primary_type': 'District Holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/leiria-day',
#     'urlid': 'portugal/leiria-day',
#     'locations': 'Leiria',
#     'states': [{'id': 848,
#       'abbrev': None,
#       'name': 'Leiria',
#       'exception': None,
#       'iso': 'pt-10'}]},
#    {'name': 'Portalegre Day',
#     'description': 'Portalegre Day is a district holiday in Portugal',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-05-23',
#      'datetime': {'year': 2024, 'month': 5, 'day': 23}},
#     'type': ['Local holiday'],
#     'primary_type': 'District Holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/portalegre-day',
#     'urlid': 'portugal/portalegre-day',
#     'locations': 'Portalegre',
#     'states': [{'id': 850,
#       'abbrev': None,
#       'name': 'Portalegre',
#       'exception': None,
#       'iso': 'pt-12'}]},
#    {'name': 'Corpus Christi',
#     'description': 'Corpus Christi is a Christian feast in honor of the Holy Eucharist.',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-05-30',
#      'datetime': {'year': 2024, 'month': 5, 'day': 30}},
#     'type': ['National holiday'],
#     'primary_type': 'National holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/corpus-christi',
#     'urlid': 'portugal/corpus-christi',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Portugal Day',
#     'description': 'Portugal Day is a national holiday in Portugal',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-06-10',
#      'datetime': {'year': 2024, 'month': 6, 'day': 10}},
#     'type': ['National holiday'],
#     'primary_type': 'National holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/portugal-day',
#     'urlid': 'portugal/portugal-day',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': "St. Anthony's Day",
#     'description': "St. Anthony's Day is a district holiday in Portugal",
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-06-13',
#      'datetime': {'year': 2024, 'month': 6, 'day': 13}},
#     'type': ['Local holiday'],
#     'primary_type': 'District Holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/st-anthony-day',
#     'urlid': 'portugal/st-anthony-day',
#     'locations': 'Lisbon, Vila Real',
#     'states': [{'id': 849,
#       'abbrev': None,
#       'name': 'Lisbon',
#       'exception': None,
#       'iso': 'pt-11'},
#      {'id': 855,
#       'abbrev': None,
#       'name': 'Vila Real',
#       'exception': None,
#       'iso': 'pt-17'}]},
#    {'name': 'June Solstice',
#     'description': 'June Solstice in Portugal (Lisbon)',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-06-20T21:50:59+01:00',
#      'datetime': {'year': 2024,
#       'month': 6,
#       'day': 20,
#       'hour': 21,
#       'minute': 50,
#       'second': 59},
#      'timezone': {'offset': '+01:00',
#       'zoneabb': 'WEST',
#       'zoneoffset': 0,
#       'zonedst': 3600,
#       'zonetotaloffset': 3600}},
#     'type': ['Season'],
#     'primary_type': 'Season',
#     'canonical_url': 'https://calendarific.com/holiday/seasons/june-solstice',
#     'urlid': 'seasons/june-solstice',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': "St. John's Day",
#     'description': "St. John's Day is a district holiday in Portugal",
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-06-24',
#      'datetime': {'year': 2024, 'month': 6, 'day': 24}},
#     'type': ['Local holiday'],
#     'primary_type': 'District Holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/st-john-day',
#     'urlid': 'portugal/st-john-day',
#     'locations': 'Porto, Braga',
#     'states': [{'id': 851,
#       'abbrev': None,
#       'name': 'Porto',
#       'exception': None,
#       'iso': 'pt-13'},
#      {'id': 842,
#       'abbrev': None,
#       'name': 'Braga',
#       'exception': None,
#       'iso': 'pt-03'}]},
#    {'name': "St. Peter's Day",
#     'description': "St. Peter's Day is a district holiday in Portugal",
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-06-29',
#      'datetime': {'year': 2024, 'month': 6, 'day': 29}},
#     'type': ['Local holiday'],
#     'primary_type': 'District Holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/st-peter-day',
#     'urlid': 'portugal/st-peter-day',
#     'locations': 'Évora',
#     'states': [{'id': 845,
#       'abbrev': None,
#       'name': 'Évora',
#       'exception': None,
#       'iso': 'pt-07'}]},
#    {'name': 'Madeira Day',
#     'description': 'Madeira Day is a regional holiday in Portugal',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-07-01',
#      'datetime': {'year': 2024, 'month': 7, 'day': 1}},
#     'type': ['Local holiday'],
#     'primary_type': 'Regional Holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/madeira-day',
#     'urlid': 'portugal/madeira-day',
#     'locations': 'Madeira',
#     'states': [{'id': 210,
#       'abbrev': None,
#       'name': 'Madeira',
#       'exception': None,
#       'iso': 'pt-30'}]},
#    {'name': "St. Elizabeth's Day",
#     'description': "St. Elizabeth's Day is a district holiday in Portugal",
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-07-04',
#      'datetime': {'year': 2024, 'month': 7, 'day': 4}},
#     'type': ['Local holiday'],
#     'primary_type': 'District Holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/st-elizabeth-day',
#     'urlid': 'portugal/st-elizabeth-day',
#     'locations': 'Coimbra',
#     'states': [{'id': 844,
#       'abbrev': None,
#       'name': 'Coimbra',
#       'exception': None,
#       'iso': 'pt-06'}]},
#    {'name': 'Assumption of Mary',
#     'description': 'The Christian feast of the Assumption of Mary is on or around Aug 15 in most countries. A few celebrate Assumption Day at other times of the year.',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-08-15',
#      'datetime': {'year': 2024, 'month': 8, 'day': 15}},
#     'type': ['National holiday'],
#     'primary_type': 'National holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/assumption',
#     'urlid': 'portugal/assumption',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Our Lady of Sorrows',
#     'description': 'Our Lady of Sorrows is a district holiday in Portugal',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-08-20',
#      'datetime': {'year': 2024, 'month': 8, 'day': 20}},
#     'type': ['Local holiday'],
#     'primary_type': 'District Holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/our-lady-of-sorrows',
#     'urlid': 'portugal/our-lady-of-sorrows',
#     'locations': 'Viana do Castelo',
#     'states': [{'id': 854,
#       'abbrev': None,
#       'name': 'Viana do Castelo',
#       'exception': None,
#       'iso': 'pt-16'}]},
#    {'name': 'Our Lady of Graces',
#     'description': 'Our Lady of Graces is a district holiday in Portugal',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-08-22',
#      'datetime': {'year': 2024, 'month': 8, 'day': 22}},
#     'type': ['Local holiday'],
#     'primary_type': 'District Holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/our-lady-of-graces',
#     'urlid': 'portugal/our-lady-of-graces',
#     'locations': 'Bragança',
#     'states': [{'id': 589,
#       'abbrev': None,
#       'name': 'Bragança',
#       'exception': None,
#       'iso': 'pt-04'}]},
#    {'name': 'Faro Day',
#     'description': 'Faro Day is a district holiday in Portugal',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-09-07',
#      'datetime': {'year': 2024, 'month': 9, 'day': 7}},
#     'type': ['Local holiday'],
#     'primary_type': 'District Holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/faro-day',
#     'urlid': 'portugal/faro-day',
#     'locations': 'Faro',
#     'states': [{'id': 846,
#       'abbrev': None,
#       'name': 'Faro',
#       'exception': None,
#       'iso': 'pt-08'}]},
#    {'name': 'Birth of Bocage',
#     'description': 'Birth of Bocage is a district holiday in Portugal',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-09-15',
#      'datetime': {'year': 2024, 'month': 9, 'day': 15}},
#     'type': ['Local holiday'],
#     'primary_type': 'District Holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/birth-of-bocage',
#     'urlid': 'portugal/birth-of-bocage',
#     'locations': 'Setúbal',
#     'states': [{'id': 853,
#       'abbrev': None,
#       'name': 'Setúbal',
#       'exception': None,
#       'iso': 'pt-15'}]},
#    {'name': "St. Matthew's Day",
#     'description': "St. Matthew's Day is a district holiday in Portugal",
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-09-21',
#      'datetime': {'year': 2024, 'month': 9, 'day': 21}},
#     'type': ['Local holiday'],
#     'primary_type': 'District Holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/st-matthew-day',
#     'urlid': 'portugal/st-matthew-day',
#     'locations': 'Viseu',
#     'states': [{'id': 856,
#       'abbrev': None,
#       'name': 'Viseu',
#       'exception': None,
#       'iso': 'pt-18'}]},
#    {'name': 'September Equinox',
#     'description': 'September Equinox in Portugal (Lisbon)',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-09-22T13:43:33+01:00',
#      'datetime': {'year': 2024,
#       'month': 9,
#       'day': 22,
#       'hour': 13,
#       'minute': 43,
#       'second': 33},
#      'timezone': {'offset': '+01:00',
#       'zoneabb': 'WEST',
#       'zoneoffset': 0,
#       'zonedst': 3600,
#       'zonetotaloffset': 3600}},
#     'type': ['Season'],
#     'primary_type': 'Season',
#     'canonical_url': 'https://calendarific.com/holiday/seasons/autumnal-equinox',
#     'urlid': 'seasons/autumnal-equinox',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Republic Day',
#     'description': 'Republic Day is a national holiday in Portugal',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-10-05',
#      'datetime': {'year': 2024, 'month': 10, 'day': 5}},
#     'type': ['National holiday'],
#     'primary_type': 'National holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/republic-implantation',
#     'urlid': 'portugal/republic-implantation',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Daylight Saving Time ends',
#     'description': 'Daylight Saving Time ends in Portugal',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-10-27T02:00:00+01:00',
#      'datetime': {'year': 2024,
#       'month': 10,
#       'day': 27,
#       'hour': 2,
#       'minute': 0,
#       'second': 0},
#      'timezone': {'offset': '+01:00',
#       'zoneabb': 'WEST',
#       'zoneoffset': 0,
#       'zonedst': 3600,
#       'zonetotaloffset': 3600}},
#     'type': ['Clock change/Daylight Saving Time'],
#     'primary_type': 'Clock change/Daylight Saving Time',
#     'canonical_url': 'https://calendarific.com/holiday/',
#     'urlid': None,
#     'locations': 'All',
#     'states': 'All'},
#    {'name': "All Saints' Day",
#     'description': "Many churches honor all their saints on All Saints' Day, also known as All Hallows' Day.",
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-11-01',
#      'datetime': {'year': 2024, 'month': 11, 'day': 1}},
#     'type': ['National holiday'],
#     'primary_type': 'National holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/all-saints-day',
#     'urlid': 'portugal/all-saints-day',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Foral of Sancho I',
#     'description': 'Foral of Sancho I is a district holiday in Portugal',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-11-27',
#      'datetime': {'year': 2024, 'month': 11, 'day': 27}},
#     'type': ['Local holiday'],
#     'primary_type': 'District Holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/foral-of-sancho-i',
#     'urlid': 'portugal/foral-of-sancho-i',
#     'locations': 'Guarda',
#     'states': [{'id': 847,
#       'abbrev': None,
#       'name': 'Guarda',
#       'exception': None,
#       'iso': 'pt-09'}]},
#    {'name': 'Restoration of Independence',
#     'description': 'Restoration of Independence is a national holiday in Portugal',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-12-01',
#      'datetime': {'year': 2024, 'month': 12, 'day': 1}},
#     'type': ['National holiday'],
#     'primary_type': 'National holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/restoration-of-independence',
#     'urlid': 'portugal/restoration-of-independence',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Feast of the Immaculate Conception',
#     'description': 'The Feast of the Immaculate Conception is a Christian observance on December 8 each year.',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-12-08',
#      'datetime': {'year': 2024, 'month': 12, 'day': 8}},
#     'type': ['National holiday'],
#     'primary_type': 'National holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/immaculate-conception',
#     'urlid': 'portugal/immaculate-conception',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'December Solstice',
#     'description': 'December Solstice in Portugal (Lisbon)',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-12-21T09:20:34+00:00',
#      'datetime': {'year': 2024,
#       'month': 12,
#       'day': 21,
#       'hour': 9,
#       'minute': 20,
#       'second': 34},
#      'timezone': {'offset': '+00:00',
#       'zoneabb': 'WET',
#       'zoneoffset': 0,
#       'zonedst': 0,
#       'zonetotaloffset': 0}},
#     'type': ['Season'],
#     'primary_type': 'Season',
#     'canonical_url': 'https://calendarific.com/holiday/seasons/december-solstice',
#     'urlid': 'seasons/december-solstice',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Christmas Eve',
#     'description': 'Christmas Eve is the day before Christmas Day and falls on December 24 in the Gregorian calendar.',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-12-24',
#      'datetime': {'year': 2024, 'month': 12, 'day': 24}},
#     'type': ['Observance'],
#     'primary_type': 'Observance',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/christmas-eve',
#     'urlid': 'portugal/christmas-eve',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Christmas Day',
#     'description': 'Christmas Day is one of the biggest Christian celebrations and falls on December 25 in the Gregorian calendar.',
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-12-25',
#      'datetime': {'year': 2024, 'month': 12, 'day': 25}},
#     'type': ['National holiday'],
#     'primary_type': 'National holiday',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/christmas-day',
#     'urlid': 'portugal/christmas-day',
#     'locations': 'All',
#     'states': 'All'},
#    {'name': "New Year's Eve",
#     'description': "New Year's Eve is the last day of the year, December 31, in the Gregorian calendar.",
#     'country': {'id': 'pt', 'name': 'Portugal'},
#     'date': {'iso': '2024-12-31',
#      'datetime': {'year': 2024, 'month': 12, 'day': 31}},
#     'type': ['Observance'],
#     'primary_type': 'Observance',
#     'canonical_url': 'https://calendarific.com/holiday/portugal/new-year-eve',
#     'urlid': 'portugal/new-year-eve',
#     'locations': 'All',
#     'states': 'All'}]}}

# %% [markdown]
# # API with O Authentication: The Noun Project

# %% [markdown]
# OAuth (Open Authorization) is a standard protocol that allows third-party applications to access resources or data on behalf of a user without exposing their login credentials.
#
# It is commonly used to grant access to APIs in a secure and controlled manner.

# %%
# ! pip install requests-oauthlib

# %%
from requests_oauthlib import OAuth1

## temporary access tokens and secret keys (more secure)
another_auth = OAuth1("6c01fdf9862c4c6fb4ed8fed190f1103", "14af8d8b79a44680bceae9dd98d62531")

##  entry point for interacting with the API and accessing its functionalities, data, or resources

endpoint = "https://api.thenounproject.com/v2/icon/83" ## unique identifier or resource identifier

response = requests.get(endpoint, auth=another_auth)
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'{\n  "icon": {\n    "attribution": "Truck by Public Domain Nouns from Noun Project",\n    "id": "83",\n    "icon_url": "https://static.thenounproject.com/svg_clean/83.svg?Expires=1771954829&Signature=Vk8Ybo3Ypr-M5teJKiFP8o6dcrUc2GmxUta~Ox45A6~4XaoKaZ3I2QMKMOKAKn7LF~4O6Tjqc-v9xxF2cY6YekSg8PG3bs0vda~ObbGNgKeOfn4hLbOYQe9R9o6o7MXVz41~0nSt8bMCMOUEVqLwpG4Gtkh22fk4zucrdC0qKps_&Key-Pair-Id=APKAI5ZVHAXN65CHVU2Q",\n    "license_description": "public-domain",\n    "permalink": "/icon/truck-83/",\n    "term": "Truck",\n    "thumbnail_url": "https://static.thenounproject.com/png/83-200.png",\n    "collections": [],\n    "tags": [\n      "lorry",\n      "truck"\n    ],\n    "styles": [\n      {\n        "style": "solid"\n      }\n    ],\n    "creator": {\n      "name": "Public Domain Nouns",\n      "permalink": "/creator/public-domain-nouns/",\n      "username": "public-domain-nouns"\n    }\n  },\n  "generated_at": "2026-02-24 16:40:29.100508",\n  "total": 1,\n  "usage_limits": {\n    "monthly": {\n      "limit": 5000,\n      "usage": 15\n    }\n  }\n}'

# %% [markdown]
# ## How to read the content?

# %% [markdown]
# bytes is a built-in data type that represents sequences of bytes, which are immutable (Once a bytes object is created, it cannot be modified. ). It is commonly used to handle binary data, such as the content of files, images, or network communication.

# %%
import json

# %%
type(response.content)
# Out:
# bytes

# %%
byte_string = response.content

json_string = byte_string.decode('utf-8')
json_string
# Out:
# '{\n  "icon": {\n    "attribution": "Truck by Public Domain Nouns from Noun Project",\n    "id": "83",\n    "icon_url": "https://static.thenounproject.com/svg_clean/83.svg?Expires=1771954829&Signature=Vk8Ybo3Ypr-M5teJKiFP8o6dcrUc2GmxUta~Ox45A6~4XaoKaZ3I2QMKMOKAKn7LF~4O6Tjqc-v9xxF2cY6YekSg8PG3bs0vda~ObbGNgKeOfn4hLbOYQe9R9o6o7MXVz41~0nSt8bMCMOUEVqLwpG4Gtkh22fk4zucrdC0qKps_&Key-Pair-Id=APKAI5ZVHAXN65CHVU2Q",\n    "license_description": "public-domain",\n    "permalink": "/icon/truck-83/",\n    "term": "Truck",\n    "thumbnail_url": "https://static.thenounproject.com/png/83-200.png",\n    "collections": [],\n    "tags": [\n      "lorry",\n      "truck"\n    ],\n    "styles": [\n      {\n        "style": "solid"\n      }\n    ],\n    "creator": {\n      "name": "Public Domain Nouns",\n      "permalink": "/creator/public-domain-nouns/",\n      "username": "public-domain-nouns"\n    }\n  },\n  "generated_at": "2026-02-24 16:40:29.100508",\n  "total": 1,\n  "usage_limits": {\n    "monthly": {\n      "limit": 5000,\n      "usage": 15\n    }\n  }\n}'

# %%
json_object = json.loads(json_string)
type(json_object)
# Out:
# dict

# %%
json_object
# Out:
# {'icon': {'attribution': 'Truck by Public Domain Nouns from Noun Project',
#   'id': '83',
#   'icon_url': 'https://static.thenounproject.com/svg_clean/83.svg?Expires=1771954829&Signature=Vk8Ybo3Ypr-M5teJKiFP8o6dcrUc2GmxUta~Ox45A6~4XaoKaZ3I2QMKMOKAKn7LF~4O6Tjqc-v9xxF2cY6YekSg8PG3bs0vda~ObbGNgKeOfn4hLbOYQe9R9o6o7MXVz41~0nSt8bMCMOUEVqLwpG4Gtkh22fk4zucrdC0qKps_&Key-Pair-Id=APKAI5ZVHAXN65CHVU2Q',
#   'license_description': 'public-domain',
#   'permalink': '/icon/truck-83/',
#   'term': 'Truck',
#   'thumbnail_url': 'https://static.thenounproject.com/png/83-200.png',
#   'collections': [],
#   'tags': ['lorry', 'truck'],
#   'styles': [{'style': 'solid'}],
#   'creator': {'name': 'Public Domain Nouns',
#    'permalink': '/creator/public-domain-nouns/',
#    'username': 'public-domain-nouns'}},
#  'generated_at': '2026-02-24 16:40:29.100508',
#  'total': 1,
#  'usage_limits': {'monthly': {'limit': 5000, 'usage': 15}}}

# %%
## extract the URL
json_object['icon']['icon_url']
# Out:
# 'https://static.thenounproject.com/svg_clean/83.svg?Expires=1771954829&Signature=Vk8Ybo3Ypr-M5teJKiFP8o6dcrUc2GmxUta~Ox45A6~4XaoKaZ3I2QMKMOKAKn7LF~4O6Tjqc-v9xxF2cY6YekSg8PG3bs0vda~ObbGNgKeOfn4hLbOYQe9R9o6o7MXVz41~0nSt8bMCMOUEVqLwpG4Gtkh22fk4zucrdC0qKps_&Key-Pair-Id=APKAI5ZVHAXN65CHVU2Q'

# %%
## convert back to string
json.dumps(json_object, indent=1)
# Out:
# '{\n "icon": {\n  "attribution": "Truck by Public Domain Nouns from Noun Project",\n  "id": "83",\n  "icon_url": "https://static.thenounproject.com/svg_clean/83.svg?Expires=1771954829&Signature=Vk8Ybo3Ypr-M5teJKiFP8o6dcrUc2GmxUta~Ox45A6~4XaoKaZ3I2QMKMOKAKn7LF~4O6Tjqc-v9xxF2cY6YekSg8PG3bs0vda~ObbGNgKeOfn4hLbOYQe9R9o6o7MXVz41~0nSt8bMCMOUEVqLwpG4Gtkh22fk4zucrdC0qKps_&Key-Pair-Id=APKAI5ZVHAXN65CHVU2Q",\n  "license_description": "public-domain",\n  "permalink": "/icon/truck-83/",\n  "term": "Truck",\n  "thumbnail_url": "https://static.thenounproject.com/png/83-200.png",\n  "collections": [],\n  "tags": [\n   "lorry",\n   "truck"\n  ],\n  "styles": [\n   {\n    "style": "solid"\n   }\n  ],\n  "creator": {\n   "name": "Public Domain Nouns",\n   "permalink": "/creator/public-domain-nouns/",\n   "username": "public-domain-nouns"\n  }\n },\n "generated_at": "2026-02-24 16:40:29.100508",\n "total": 1,\n "usage_limits": {\n  "monthly": {\n   "limit": 5000,\n   "usage": 15\n  }\n }\n}'

# %%
type(json.dumps(json_object))
# Out:
# str
