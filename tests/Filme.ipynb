# %%
import requests

# Test query für OMDb
data = requests.get("http://www.omdbapi.com/?apikey=KEY&t=Inception&plot=full").json()

print("Filmtitel: " + data['Title'])
print("Jahr:      " + data['Year'])
print("Metascore: " + data['Metascore'])
print("Oscars:    " + data['Awards'])
print("---------------------------------")
print("Handlung:  " + data['Plot'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 6
#       3 # Test query für OMDb
#       4 data = requests.get("http://www.omdbapi.com/?apikey=KEY&t=Inception&plot=full").json()
# ----> 6 print("Filmtitel: " + data['Title'])
#       7 print("Jahr:      " + data['Year'])
#       8 print("Metascore: " + data['Metascore'])
#
# KeyError: 'Title'
