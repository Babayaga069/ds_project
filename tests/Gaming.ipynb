# %%
import requests

#Test queries for Steam Web API

#Number of current players for CS 2
steam_url = "https://api.steampowered.com/ISteamUserStats/GetNumberOfCurrentPlayers/v1/?appid=730"
steam_response = requests.get(steam_url)
print(steam_response.json()['response']['player_count'])

steam_url1 = "https://api.steampowered.com/ISteamUserStats/GetGlobalAchievementPercentagesForApp/v2/?gameid=620"
steam_response1= requests.get(steam_url1)
print(steam_response1.json())
# Out:
# 1117777
# {}

# %%
import requests

#Test queries for Twitch API

# %%
import requests
import json

#Test queries for RAWG.io API

#get list of parent platforms (parent platform is "playstation", "children are ps 1, ps 2, etc.")
rawg_url = 'https://api.rawg.io/api/platforms/lists/parents?key=INSERT_KEY'
rawg_response = requests.get(rawg_url)
#print(rawg_response.json()['results'])

print(json.dumps(rawg_response.json()['results'][1],indent=1))
# Out:
# [{'id': 1, 'name': 'PC', 'slug': 'pc', 'platforms': [{'id': 4, 'name': 'PC', 'slug': 'pc', 'games_count': 560362, 'image_background': 'https://media.rawg.io/media/games/73e/73eecb8909e0c39fb246f457b5d6cbbe.jpg', 'image': None, 'year_start': None, 'year_end': None}]}, {'id': 2, 'name': 'PlayStation', 'slug': 'playstation', 'platforms': [{'id': 187, 'name': 'PlayStation 5', 'slug': 'playstation5', 'games_count': 1440, 'image_background': 'https://media.rawg.io/media/games/253/2534a46f3da7fa7c315f1387515ca393.jpg', 'image': None, 'year_start': 2020, 'year_end': None}, {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4', 'games_count': 6976, 'image_background': 'https://media.rawg.io/media/games/b45/b45575f34285f2c4479c9a5f719d972e.jpg', 'image': None, 'year_start': None, 'year_end': None}, {'id': 16, 'name': 'PlayStation 3', 'slug': 'playstation3', 'games_count': 3164, 'image_background': 'https://media.rawg.io/media/games/bc0/bc06a29ceac58652b684deefe7d56099.jpg', 'image': None, 'year_start': None, 'year_end': None}, {'id': 15, 'name': 'PlayStation 2', 'slug': 'playstation2', 'games_count': 2073, 'image_background': 'https://media.rawg.io/media/games/791/791abcd56601482964f0fee6d8ab6a61.jpeg', 'image': None, 'year_start': None, 'year_end': None}, {'id': 27, 'name': 'PlayStation', 'slug': 'playstation1', 'games_count': 1684, 'image_background': 'https://media.rawg.io/media/games/786/786f9a212646c793ccbad196cba2cf36.jpg', 'image': None, 'year_start': None, 'year_end': None}, {'id': 19, 'name': 'PS Vita', 'slug': 'ps-vita', 'games_count': 1458, 'image_background': 'https://media.rawg.io/media/games/8d6/8d69eb6c32ed6acfd75f82d532144993.jpg', 'image': None, 'year_start': None, 'year_end': None}, {'id': 17, 'name': 'PSP', 'slug': 'psp', 'games_count': 1377, 'image_background': 'https://media.rawg.io/media/games/932/93221053809511fde4a0c6a9fddaf558.jpg', 'image': None, 'year_start': None, 'year_end': None}]}, {'id': 3, 'name': 'Xbox', 'slug': 'xbox', 'platforms': [{'id': 1, 'name': 'Xbox One', 'slug': 'xbox-one', 'games_count': 5729, 'image_background': 'https://media.rawg.io/media/games/7cf/7cfc9220b401b7a300e409e539c9afd5.jpg', 'image': None, 'year_start': None, 'year_end': None}, {'id': 186, 'name': 'Xbox Series S/X', 'slug': 'xbox-series-x', 'games_count': 1231, 'image_background': 'https://media.rawg.io/media/games/b29/b294fdd866dcdb643e7bab370a552855.jpg', 'image': None, 'year_start': 2020, 'year_end': None}, {'id': 14, 'name': 'Xbox 360', 'slug': 'xbox360', 'games_count': 2809, 'image_background': 'https://media.rawg.io/media/games/562/562553814dd54e001a541e4ee83a591c.jpg', 'image': None, 'year_start': None, 'year_end': None}, {'id': 80, 'name': 'Xbox', 'slug': 'xbox-old', 'games_count': 745, 'image_background': 'https://media.rawg.io/media/games/7e8/7e8890a662539b1bdefcf57409aef765.jpg', 'image': None, 'year_start': None, 'year_end': None}]}, {'id': 4, 'name': 'iOS', 'slug': 'ios', 'platforms': [{'id': 3, 'name': 'iOS', 'slug': 'ios', 'games_count': 77432, 'image_background': 'https://media.rawg.io/media/games/283/283e7e600366b0da7021883d27159b27.jpg', 'image': None, 'year_start': None, 'year_end': None}]}, {'id': 8, 'name': 'Android', 'slug': 'android', 'platforms': [{'id': 21, 'name': 'Android', 'slug': 'android', 'games_count': 52503, 'image_background': 'https://media.rawg.io/media/games/960/960b601d9541cec776c5fa42a00bf6c4.jpg', 'image': None, 'year_start': None, 'year_end': None}]}, {'id': 5, 'name': 'Apple Macintosh', 'slug': 'mac', 'platforms': [{'id': 5, 'name': 'macOS', 'slug': 'macos', 'games_count': 107992, 'image_background': 'https://media.rawg.io/media/games/bc0/bc06a29ceac58652b684deefe7d56099.jpg', 'image': None, 'year_start': None, 'year_end': None}, {'id': 55, 'name': 'Classic Macintosh', 'slug': 'macintosh', 'games_count': 674, 'image_background': 'https://media.rawg.io/media/games/38a/38af969459ad6e5de116ec8a4a84218c.jpg', 'image': None, 'year_start': None, 'year_end': None}, {'id': 41, 'name': 'Appl ...
# {
#  "id": 2,
#  "name": "PlayStation",
#  "slug": "playstation",
#  "platforms": [
#   {
#    "id": 187,
#    "name": "PlayStation 5",
#    "slug": "playstation5",
#    "games_count": 1440,
#    "image_background": "https://media.rawg.io/media/games/253/2534a46f3da7fa7c315f1387515ca393.jpg",
#    "image": null,
#    "year_start": 2020,
#    "year_end": null
#   },
#   {
#    "id": 18,
#    "name": "PlayStation 4",
#    "slug": "playstation4",
#    "games_count": 6976,
#    "image_background": "https://media.rawg.io/media/games/b45/b45575f34285f2c4479c9a5f719d972e.jpg",
#    "image": null,
#    "year_start": null,
#    "year_end": null
#   },
#   {
#    "id": 16,
#    "name": "PlayStation 3",
#    "slug": "playstation3",
#    "games_count": 3164,
#    "image_background": "https://media.rawg.io/media/games/bc0/bc06a29ceac58652b684deefe7d56099.jpg",
#    "image": null,
#    "year_start": null,
#    "year_end": null
#   },
#   {
#    "id": 15,
#    "name": "PlayStation 2",
#    "slug": "playstation2",
#    "games_count": 2073,
#    "image_background": "https://media.rawg.io/media/games/791/791abcd56601482964f0fee6d8ab6a61.jpeg",
#    "image": null,
#    "year_start": null,
#    "year_end": null
#   },
#   {
#    "id": 27,
#    "name": "PlayStation",
#    "slug": "playstation1",
#    "games_count": 1684,
#    "image_background": "https://media.rawg.io/media/games/786/786f9a212646c793ccbad196cba2cf36.jpg",
#    "image": null,
#    "year_start": null,
#    "year_end": null
#   },
#   {
#    "id": 19,
#    "name": "PS Vita",
#    "slug": "ps-vita",
#    "games_count": 1458,
#    "image_background": "https://media.rawg.io/media/games/8d6/8d69eb6c32ed6acfd75f82d532144993.jpg",
#    "image": null,
#    "year_start": null,
#    "year_end": null
#   },
#   {
#    "id": 17,
#    "name": "PSP",
#    "slug": "psp",
#    "games_count": 1377,
#    "image_background": "https://media.rawg.io/media/games/932/93221053809511fde4a0c6a9fddaf558.jpg",
#    "image": null,
#    "year_start": null,
#    "year_end": null
#   }
#  ]
# }
