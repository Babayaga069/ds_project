# %% [markdown]
# # ARXIV Keyword Project
#
# In diesem kleinen Beispiel Projekt finden wir heraus, zu welchen Themen in der Informatik in letzter Zeit vermehrt veröffentlicht werden.
#
# Erstmal ein paar imports und ein logger setup:

# %%
import arxiv, logging, keybert
from tqdm.notebook import tqdm
import pandas as pd
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
logging.basicConfig(level=logging.INFO)

# %% [markdown]
# ## 1. Daten sammeln
#
# Wir holen uns erstmal die Meta Daten zu den letzten 1000 Papern aus der Computer Science Kategorie. Hierzu nutzen wir die [arxiv python library](https://pypi.org/project/arxiv/), welche wiederrum auf die offizielle arxiv API zugreift. Die Ergebnisse werden dann vom neusten zum ältesten Einreichdatum sortiert.

# %%
search = arxiv.Search(
    query='cat:cs.*',
    sort_by = arxiv.SortCriterion.SubmittedDate,
    max_results = 400,
    sort_order = arxiv.SortOrder.Descending
)

# %% [markdown]
# Durch den Befehl search.results() werden die Daten tatsächlich angefragt und dann in einer FOR-Schleife in eine Liste von Dictionaries mit den Meta Daten, die wir weiterhin benötigen, eingefügt.

# %%
results = []
for paper in search.results():
    meta_data = {
        'title' : paper.title,
        'abstract' : paper.summary,
        'authors' : paper.authors,
        'date_published' : paper.published
    }
    results.append(meta_data)
# Out:
# INFO:arxiv.arxiv:Requesting 100 results at offset 0
# INFO:arxiv.arxiv:Requesting page of results
# INFO:arxiv.arxiv:Got first page; 400 of 400 results available
# INFO:arxiv.arxiv:Requesting 100 results at offset 100
# INFO:arxiv.arxiv:Sleeping for 2.994486 seconds
# INFO:arxiv.arxiv:Requesting page of results
# INFO:arxiv.arxiv:Requesting 100 results at offset 200
# INFO:arxiv.arxiv:Sleeping for 2.995272 seconds
# INFO:arxiv.arxiv:Requesting page of results
# INFO:arxiv.arxiv:Sleeping for 2.999987 seconds
# INFO:arxiv.arxiv:Requesting page of results
# INFO:arxiv.arxiv:Requesting 100 results at offset 300
# INFO:arxiv.arxiv:Sleeping for 2.995354 seconds
# INFO:arxiv.arxiv:Requesting page of results

# %% [markdown]
# Nun laden wir die Daten in ein pandas DataFrame und setzten den Index als den Timestamp an dem das Paper veröffentlicht wurde.

# %%
results_df = pd.DataFrame(results)
results_df.set_index(results_df['date_published'], inplace=True)
results_df
# Out:
#                                                                        title  \
# date_published
# 2024-02-22 18:59:58+00:00  PALO: A Polyglot Large Multimodal Model for 5B...
# 2024-02-22 18:59:56+00:00  Cameras as Rays: Pose Estimation via Ray Diffu...
# 2024-02-22 18:59:53+00:00  Demographic Bias of Expert-Level Vision-Langua...
# 2024-02-22 18:59:24+00:00  Fine-Tuning Enhances Existing Mechanisms: A Ca...
# 2024-02-22 18:59:24+00:00  WeakSAM: Segment Anything Meets Weakly-supervi...
# ...                                                                      ...
# 2024-02-21 18:36:26+00:00  Real-time 3D-aware Portrait Editing from a Sin...
# 2024-02-21 18:35:27+00:00  Asymptotics of Learning with Deep Structured (...
#
# [400 rows x 4 columns]

# %% [markdown]
# # 2. Keywords generieren

# %% [markdown]
# Arxiv hat leider keine Keywords im Angebot, also nutzen wir eine Deep Learning Methode um die Keywords aus den jeweiligen Abstracts der Paper zu extrahieren. Hier gibt es netterweise eine python bibliothek, [KeyBERT](https://maartengr.github.io/KeyBERT/), welche ein schon komplett trainiertes Modell direkt bereitstellt, dass laden wir jetzt erstmal in unser Notebook.

# %%
model = keybert.KeyBERT()
# Out:
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device: cpu

# %% [markdown]
# Als nächstes wenden wir KeyBERT auf den Titel kombiniert mit dem Abstract von jedem Paper an und **speichern jeweils aus ein und zwei Wörtern bestehende keywords ab**. Das kann ein bisschen dauern.

# %%
keywords_list = []
for row_i in tqdm(range(results_df.shape[0])):
    row = results_df.iloc[row_i]
    keywords = []
    title_abstract = row['title'] + ' ' + row['abstract'] 
    keywords.append(model.extract_keywords(title_abstract, 
                       keyphrase_ngram_range = (1,1)))
    keywords.append(model.extract_keywords(title_abstract, 
                       keyphrase_ngram_range = (1,2)))
    keywords_list.append(keywords)
# Out:
#   0%|          | 0/400 [00:00<?, ?it/s]

# %% [markdown]
# Die Keywords werden als eigene Spalte an das DataFrame angehängt.

# %%
results_df['keywords'] = keywords_list

# %%
results_df
# Out:
#                                                                        title  \
# date_published
# 2024-02-22 18:59:58+00:00  PALO: A Polyglot Large Multimodal Model for 5B...
# 2024-02-22 18:59:56+00:00  Cameras as Rays: Pose Estimation via Ray Diffu...
# 2024-02-22 18:59:53+00:00  Demographic Bias of Expert-Level Vision-Langua...
# 2024-02-22 18:59:24+00:00  Fine-Tuning Enhances Existing Mechanisms: A Ca...
# 2024-02-22 18:59:24+00:00  WeakSAM: Segment Anything Meets Weakly-supervi...
# ...                                                                      ...
# 2024-02-21 18:36:26+00:00  Real-time 3D-aware Portrait Editing from a Sin...
# 2024-02-21 18:35:27+00:00  Asymptotics of Learning with Deep Structured (...
# 2024-02-21 18:25:04+00:00  Generative Adversarial Models for Extreme Down...
# 2024-02-21 18:24:07+00:00  Meditating in Live Stream: An Autoethnographic...
# 2024-02-21 18:23:16+00:00  Analysing The Impact of Sequence Composition o...
#
#                                                                     abstract  \
# date_published
# 2024-02-22 18:59:58+00:00  In pursuit of more inclusive Vision-Language M...
# 2024-02-22 18:59:56+00:00  Estimating camera poses is a fundamental task ...
# 2024-02-22 18:59:53+00:00  Advances in artificial intelligence (AI) have ...
# 2024-02-22 18:59:24+00:00  Fine-tuning on generalized tasks such as instr...
# 2024-02-22 18:59:24+00:00  Weakly supervised visual recognition using ine...
# ...                                                                      ...
# 2024-02-21 18:36:26+00:00  This work presents 3DPE, a practical tool that...
# 2024-02-21 18:35:27+00:00  For a large class of feature maps we provide a...
# 2024-02-21 18:25:04+00:00  Addressing the challenges of climate change re...
# 2024-02-21 18:24:07+00:00  Mindfulness practice has many mental and physi...
# 2024-02-21 18:23:16+00:00  Most language model pre-training frameworks co...
#
#                                                                      authors  \
# date_published
# 2024-02-22 18:59:58+00:00  [Muhammad Maaz, Hanoona Rasheed, Abdelrahman S...
# 2024-02-22 18:59:56+00:00  [Jason Y. Zhang, Amy Lin, Moneish Kumar, Tzu-H...
# 2024-02-22 18:59:53+00:00  [Yuzhe Yang, Yujia Liu, Xin Liu, Avanti Gulhan...
# 2024-02-22 18:59:24+00:00  [Nikhil Prakash, Tamar Rott Shaham, Tal Haklay...
# 2024-02-22 18:59:24+00:00  [Lianghui Zhu, Junwei Zhou, Yan Liu, Xin Hao, ...
# ...                                                                      ...
# 2024-02-21 18:36:26+00:00  [Qingyan Bai, Yinghao Xu, Zifan Shi, Hao Ouyan...
# 2024-02-21 18:35:27+00:00  [Dominik Schröder, Daniil Dmitriev, Hugo Cui, ...
# 2024-02-21 18:25:04+00:00                            [Guiye Li, Guofeng Cao]
# 2024-02-21 18:24:07+00:00            [Jingjin Li, Jiajing Guo, Gilly Leshed]
# 2024-02-21 18:23:16+00:00  [Yu Zhao, Yuanbin Qu, Konrad Staniszewski, Szy...
#
#                                      date_published  \
# date_published
# 2024-02-22 18:59:58+00:00 2024-02-22 18:59:58+00:00
# 2024-02-22 18:59:56+00:00 2024-02-22 18:59:56+00:00
# 2024-02-22 18:59:53+00:00 2024-02-22 18:59:53+00:00
# 2024-02-22 18:59:24+00:00 2024-02-22 18:59:24+00:00
# 2024-02-22 18:59:24+00:00 2024-02-22 18:59:24+00:00
# ...                                             ...
# 2024-02-21 18:36:26+00:00 2024-02-21 18:36:26+00:00
# 2024-02-21 18:35:27+00:00 2024-02-21 18:35:27+00:00
# 2024-02-21 18:25:04+00:00 2024-02-21 18:25:04+00:00
# 2024-02-21 18:24:07+00:00 2024-02-21 18:24:07+00:00
# 2024-02-21 18:23:16+00:00 2024-02-21 18:23:16+00:00
#
#                                                                     keywords
# date_published
# 2024-02-22 18:59:58+00:00  [[(multilingual, 0.4953), (multimodal, 0.4922)...
# 2024-02-22 18:59:56+00:00  [[(pose, 0.4211), (poses, 0.3985), (cameras, 0...
# 2024-02-22 18:59:53+00:00  [[(bias, 0.3745), (biases, 0.3423), (ai, 0.329...
# 2024-02-22 18:59:24+00:00  [[(entity, 0.3534), (tracking, 0.3499), (seman...
# 2024-02-22 18:59:24+00:00  [[(supervised, 0.4445), (regularization, 0.355...
# ...                                                                      ...
# 2024-02-21 18:36:26+00:00  [[(portrait, 0.4905), (editing, 0.441), (3d, 0...
# 2024-02-21 18:35:27+00:00  [[(neural, 0.4153), (networks, 0.3634), (learn...
# 2024-02-21 18:25:04+00:00  [[(gans, 0.4554), (downscaling, 0.4483), (gan,...
# 2024-02-21 18:24:07+00:00  [[(meditation, 0.4491), (meditating, 0.4244), ...
# 2024-02-21 18:23:16+00:00  [[(distractions, 0.3943), (memorisation, 0.367...
#
# [400 rows x 5 columns]

# %% [markdown]
# Die Keywords-Liste ist jetzt eine Liste aus Listen von Keywords, um jetzt möglichst einfach die Keywords zu zählen, wandeln wir diese in nur eine liste von keywords um mit Hilfe von dieser flatten Funktion:

# %%
def flatten(xss):
    return [x for xs in xss for x in xs]

# %%
flattened_keywords = flatten(flatten(keywords_list))

# %%
flattened_keywords = [item[0] for item in flattened_keywords]

# %% [markdown]
# Mit Hilfe von der python set funktion könnnen wir die einzigartigen keywords in der gesamten liste zählen.

# %%
len(flattened_keywords)
# Out:
# 4000

# %%
len(set(flattened_keywords))
# Out:
# 3040

# %% [markdown]
# #### Datensatz aus nur Keywords
# Jetzt suchen wir die häufigsten Keywords und speichern sie in einem eigenen DataFrame ab, wir filtern davor Worte die nur einmalig vorkommen und sortieren das ganze dann nach der absteigend nach der Häufigkeit.

# %%
keywords_df = pd.DataFrame()
keywords_df['words'] = Counter(flattened_keywords).keys()
keywords_df['numbers'] = Counter(flattened_keywords).values()
frequent_words = keywords_df.loc[keywords_df['numbers'] > 1].sort_values(by='numbers', ascending=False)
frequent_words
# Out:
#                    words  numbers
# 185             learning       31
# 3               language       23
# 68             attention       22
# 35       language models       20
# 104               visual       14
# ...                  ...      ...
# 915            diversity        2
# 918   imitation learning        2
# 941            intrusion        2
# 968       digitalization        2
# 2943                flow        2
#
# [378 rows x 2 columns]

# %% [markdown]
# # 3. Visualizierung der Daten

# %% [markdown]
# Und jetzt können wir direkt aus dem Counter das Ganze als Wordcloud visualisieren.

# %%
wordcloud = WordCloud(background_color="white", 
                      width=2500, 
                      height=1000, 
                      scale=2.0, 
                      min_font_size=6).fit_words(dict(Counter(flattened_keywords))).to_file('arxiv_word_cloud.png')

# %%
plt.imshow(wordcloud)
# plt.savefig('arxiv_word_cloud.png')
plt.show()

# %% [markdown]
# # Aufgaben
#
# 1. Probiert die WordCloud direkt aus den Titel und/oder den Abstracts der Paper zu erzeugen, ohne KeyBERT und vergleicht das Ergebnis. Sind also die häufigsten Worte die verwendet werden gleich zu den Keywords? Wenn nicht was ist das Problem und wie könnte man dies einfach umgehen? *Hint: Stop Words (auch direkt in der [word cloud bib](https://amueller.github.io/word_cloud/index.html))*

# %% [markdown]
# 2. Statt die vorgefertigte *arxiv* libary zu nutzen, versucht die Daten aus der API nur mit Hilfe der pyhton internen requests Bibliothek anzufragen. Passt dabei auf die Hinweise auf der [arxiv API Webseite](https://arxiv.org/help/api/) auf und startet bitte nicht eine DDOS Attacke auf die Server (Baut also Wartezeiten ein!)

# %%
import requests

# %% [markdown]
# 3. Bonusaufgabe - Erstellt einen Co-Autoren Graph aus dem Autoren Attribut der Paper und visualsiert diesen. Dieser Artikel könnte helfen https://towardsdatascience.com/visualizing-networks-in-python-d70f4cbeb259
