# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# ── CSV laden (gleicher Ordner wie dieses Script) ──────────────
script_dir = os.path.dirname(os.path.abspath(__file__))
csv_path = os.path.join(script_dir, "movies.csv")

df = pd.read_csv(csv_path)
print("Geladene Spalten:", df.columns.tolist())
print(df.head())

# ── Korrelationsanalyse (Kernfrage Q9) ─────────────────────────
# Fragt: Hängt Pre-Release Hype mit Erfolg zusammen?
corr_cols = ["avg_trend_before", "max_trend_before", "revenue", "roi", "vote_average"]
corr = df[corr_cols].corr()

print("\nKorrelationsmatrix:")
print(corr.round(2))

# ── Plot 1: Hype vs. Revenue ───────────────────────────────────
plt.figure(figsize=(8, 5))
plt.scatter(df["avg_trend_before"], df["revenue"] / 1_000_000)
for _, row in df.iterrows():
    plt.annotate(row["title"], (row["avg_trend_before"], row["revenue"] / 1_000_000),
                 fontsize=8, xytext=(5, 5), textcoords="offset points")
plt.xlabel("Avg. Google Trends (Pre-Release)")
plt.ylabel("Revenue (Mio. $)")
plt.title("Pre-Release Hype vs. Revenue")
plt.tight_layout()
plt.savefig("plot_hype_vs_revenue.png")
plt.show()
print("✅ Gespeichert: plot_hype_vs_revenue.png")

# ── Plot 2: Hype vs. Vote Average ─────────────────────────────
plt.figure(figsize=(8, 5))
plt.scatter(df["avg_trend_before"], df["vote_average"], color="orange")
for _, row in df.iterrows():
    plt.annotate(row["title"], (row["avg_trend_before"], row["vote_average"]),
                 fontsize=8, xytext=(5, 5), textcoords="offset points")
plt.xlabel("Avg. Google Trends (Pre-Release)")
plt.ylabel("TMDB Vote Average")
plt.title("Pre-Release Hype vs. Kritische Bewertung")
plt.tight_layout()
plt.savefig("plot_hype_vs_rating.png")
plt.show()
print("✅ Gespeichert: plot_hype_vs_rating.png")
